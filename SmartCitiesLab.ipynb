# %% [markdown]
# # Cities in Montion Index

# %% [markdown]
# We want to analyze the following dataset to understand the factors that drive the performance of a city.  The performance of a city is measured by CIMI (Cities in Motion Index), and it is our dependent variable, where the highest value is 100 and the lowest 0.
# We'll work with the predictors (from column E to column M), where the highest value is 1 and the lowest is 199. We need to first standardize the model and second apply a dimensionality reduction method such as PCA to analyze the dimensions.
# Link: https://www.iese.edu/media/research/pdfs/ST-0633-E.pdf

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load the dataset and show the first 5 rows
# Out:
#    Ranking      City         Country    ICIM  Economy  Human Capital  \
# 0        1    London  United Kingdom  100.00        7              1
# 1        2  New York             USA   98.25        1              3
# 2        3     Paris          France   84.99        9              5
# 3        4     Tokyo           Japan   80.30        2             10
# 4        5    Berlin         Germany   76.42       94              7
#
#    Social Cohesion  Environment  Governance  Urban Planning  \
# 0               25           17           2               1
# 1              121          105          10               2
# 2               67           49          17              34
# 3               41           25           9             112
# 4               40           21           3               5
#
#    International Profile  Technology  Mobility and Transportation  \
# 0                      1          18                            4
# ...

# %%
# Selecting predictor variables and show the first 5 rows
# Out:
#    Economy  Human Capital  Social Cohesion  Environment  Governance  \
# 0        7              1               25           17           2
# 1        1              3              121          105          10
# 2        9              5               67           49          17
# 3        2             10               41           25           9
# 4       94              7               40           21           3
#
#    Urban Planning  International Profile  Technology  \
# 0               1                      1          18
# 1               2                      3           6
# 2              34                      2          27
# 3             112                      6           9
# 4               5                     14          39
#
#    Mobility and Transportation
# 0                            4
# 1                            1
# 2                            3
# 3                           62
# 4                            7

# %%
# Standarde the data
# Out:
# array([[-1.60903297, -1.72261177, -1.26829658, ..., -1.72261177,
#         -1.40080517, -1.66582237],
#        [-1.72261177, -1.68475217,  0.54896419, ..., -1.68475217,
#         -1.62796277, -1.72261177],
#        [-1.57117337, -1.64689257, -0.47324499, ..., -1.70368197,
#         -1.23043698, -1.68475217],
#        ...,
#        [ 1.72261177,  1.60903297,  1.40080517, ...,  1.23043698,
#          1.53331377,  1.21150718],
#        [ 1.32508598,  1.59010317,  1.70368197, ...,  1.70368197,
#          1.51438397,  1.43866477],
#        [ 1.60903297,  1.51438397,  1.62796277, ...,  1.62796277,
#          1.72261177,  1.72261177]])

# %%
# Apply the scaler
# Out:
# StandardScaler()

# %%
# Apply the PCA class with 2 components
# Out:
# PCA(n_components=2)

# %%
# Check the shape
# Out:
# (183, 2)

# %%
# Plot the model with the first and second components

# %%
# Create a DataFrame to show the principal components and the explained variance
# Display explained variance for each principal component
# Display the results
# Out:
#         PC1       PC2
# 0 -4.740287 -0.096222
# 1 -3.804316  1.901520
# 2 -3.924120  0.558044
# 3 -3.509540  0.257829
# 4 -3.745725 -0.501538
#   Principal Component  Explained Variance Ratio
# 0                 PC1                  0.655342
# 1                 PC2                  0.114351

# %% [markdown]
# ### Check All the Predictors

# %%
# Standardize the data
# Apply PCA
# Create a DataFrame to show the principal components and the explained variance
# Display explained variance for each principal component
# Display the results
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -4.740287 -0.096222 -0.305004  0.163878  0.071678 -0.133217  0.211665
# 1 -3.804316  1.901520 -1.175169  0.021454  0.395061  0.474011 -0.063479
# 2 -3.924120  0.558044 -0.483867  0.036297  0.672692 -0.074151  0.205828
# 3 -3.509540  0.257829  1.304545  0.266022  1.245826 -0.243522 -0.158422
# 4 -3.745725 -0.501538 -1.020960  0.709296 -0.067512 -0.748385 -0.413952
#
#         PC8       PC9
# 0  0.221405 -0.066390
# 1  0.298005 -0.051712
# 2  0.267792 -0.031809
# 3  0.220800  0.178608
# 4 -0.307580  0.016910
#   Principal Component  Explained Variance Ratio
# 0                 PC1                  0.655342
# 1                 PC2                  0.114351
# 2                 PC3                  0.052931
# 3                 PC4                  0.048178
# 4                 PC5                  0.039767
# 5                 PC6                  0.032343
# 6                 PC7                  0.022476
# ...

# %%
# Apply PCA with only three components
# Create a DataFrame to show the three principal components
# Display the DataFrame and the explained variance
# Out:
#         PC1       PC2       PC3
# 0 -4.740287 -0.096222 -0.305004
# 1 -3.804316  1.901520 -1.175169
# 2 -3.924120  0.558044 -0.483867
# 3 -3.509540  0.257829  1.304545
# 4 -3.745725 -0.501538 -1.020960
#   Principal Component  Explained Variance Ratio
# 0                 PC1                  0.655342
# 1                 PC2                  0.114351
# 2                 PC3                  0.052931

# %%
# Create a heatmap to map the relationship between PC1, PC2 and PC3 with the original predictor variables

# %% [markdown]
# * Red indicates a positive correlation, meaning as the predictor value increases, the principal component value also tends to increase.
# * Blue indicates a negative correlation, signifying an inverse relationship between the predictor and the component.
